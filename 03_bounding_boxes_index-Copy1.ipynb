# %%
import pytesseract
import cv2

# %%
image = cv2.imread("dataset/dataset/training_data/images/00040534.png")
base_image = image.copy()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite("temp/index_gray.png", gray)
# Out:
# True

# %%
blur = cv2.GaussianBlur(gray, (7,7), 0)

# %%
cv2.imwrite("temp/index_blur.png", blur)
# Out:
# True

# %%
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# %%
cv2.imwrite("temp/index_thresh.png", thresh)
# Out:
# True

# %%
kernal = cv2.getStructuringElement(cv2.MORPH_RECT, (25, 1))

# %%
cv2.imwrite("temp/index_kernal.png", kernal)
# Out:
# True

# %%
dilate = cv2.dilate(thresh, kernal, iterations=1)

# %%
cv2.imwrite("temp/index_dilate.png", dilate)
# Out:
# True

# %%
def sort_contours(cnts):
    boundingBoxes = [cv2.boundingRect(c) for c in cnts]
    (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes), key=lambda b: b[1][1]))
    return cnts

# %%
cnts = sort_contours(cnts)

# %%
cnts, hierarchy = cv2.findContours(dilate, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
cnts = cnts[0] if len(cnts) == 2 else cents[1]

# %%
cnts = sorted(cnts, key=lambda x: cv2.boundingRect(x)[0])

# %%
results  = []
for c in cnts:
    x, y, w, h = cv2.boundingRect(c)
    if h > 200 and w > 20:
        roi = image[y:y+h, x:x+h]
        cv2.rectangle(image, (x, y), (x+w, y+h), (36, 255, 12), 2)
        ocr_result = pytesseract.image_to_string(roi)
        ocr_result = ocr_result.split("\n")
        for item in ocr_result:
            results.append(item)
cv2.imwrite("temp/index_bbox_new.png", image)
# Out:
# True

# %%
print (results)
# Out:
# ['ACUTE TOXICITY IN MICE', '', '3-Hydroxy-3-methylbutanoic acid (Tur 13)', '', '[cowrouno', '', 'Lorillard - Organic Chemistry 9. sp yo__OR39-23 vernon AY.', '', '373/79', 'Joare necenveo Unk. resten 12/28/78 neronrso 10/6/80, Update', '', 'source', '', 'H._S. Tong & M.S. Forte! nortooonexoe BIOL 4-23', '', 'nvesnicarons', '', 'ssonarnes)', '', '—- pd até (bi 2 Tooke)', '', 'eran or wee _SWiss-Webster x bare necengo UX ~', '', 'AVERAGE WEIGHTIRANGE (GM) Camm Research', '', 'ROUTE oF couroUNO ADMINISTRATION cxro. ow marion', '', 'Jcowowno venice 9), 5 METH CELUKOSE 1 com on sue omen', '', '(rong BS con (90 OGRE este)', '', '1800 1/6', '', '10 2160 0/6', '', '10 2592 0/6', '', '10 3732 3/6', '', '10 4479 6/6', '', 'rcrenence roncarcusnon Litchfield, J. T. and Wilcoxin, F., J. of Pharmacol.', '', 'and Exper. Ther., 90:99, 1948.', '', 'toseex conromnce mrs _3.5 (3.1 to 3.9) q/kg', '', 'concwson THIS compound appears to act _as_a CNS depressant with symptons', '', 'of respiratory depression, constriction of blood vessels, and in-', '', 'activity. Survivors recovered in 48 hours. The recommended safe', '', 'dose for a single trial by inhalation in man is 0.3 mg.', '', '| Copies to the Followin: Dr. H. J, Minnemeyer', '', 'Ns. b. 5. Gray', '', '']

# %%
entities = []
for item in results:
    item = item.strip().replace("\n", "")
    item = item.split(" ")[0]
    if len(item) > 2:
        if item[0] == "A" and "-" not in item:
            item = item.split(".")[0].replace(",", "").replace(";", "")
            entities.append(item)

# %%
print (entities)
# Out:
# ['ACUTE', 'AVERAGE']

# %%
entities = list(set(entities))

# %%
print (entities)
# Out:
# ['ACUTE']

# %%
entities.sort()

# %%
print (entities)
# Out:
# ['ACUTE']
